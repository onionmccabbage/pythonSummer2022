# %% [markdown]
# # Pandas introduction

# %%
# we always begin with...
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# we can build structures for our data
# Pandas offers the 'DataFrame' structure
d = pd.DataFrame()

# %%
# we can import from csv or from Excel straight in to a DataFrame
df = pd.read_excel(io='../Data/sample_data.xls', sheet_name='SP500', index_col='Symbol')
df
# Out:
#                           Name                  Sector   Price  \
# Symbol
# MMM                 3M Company             Industrials  222.89
# AOS            A.O. Smith Corp             Industrials   60.24
# ABT        Abbott Laboratories             Health Care   56.27
# ABBV               AbbVie Inc.             Health Care  108.48
# ACN              Accenture plc  Information Technology  150.51
# ...                        ...                     ...     ...
# XYL                 Xylem Inc.             Industrials   70.24
# YUM            Yum! Brands Inc  Consumer Discretionary   76.30
# ZBH     Zimmer Biomet Holdings             Health Care  115.53
# ZION             Zions Bancorp              Financials   50.71
# ZTS                     Zoetis             Health Care   71.51
#
#         Price/Earnings  Earnings/Share  52 Week High  52 Week Low
# Symbol
# MMM              24.31            7.92        259.77      175.490
# ...

# %%
df.head(9)
df.tail()
df['Name'] # return just that column
whichColumns = ['Name', 'Sector', 'Price'] # a Python list
df[whichColumns] # note the double square brackets
# Out:
#                           Name                  Sector   Price
# Symbol
# MMM                 3M Company             Industrials  222.89
# AOS            A.O. Smith Corp             Industrials   60.24
# ABT        Abbott Laboratories             Health Care   56.27
# ABBV               AbbVie Inc.             Health Care  108.48
# ACN              Accenture plc  Information Technology  150.51
# ...                        ...                     ...     ...
# XYL                 Xylem Inc.             Industrials   70.24
# YUM            Yum! Brands Inc  Consumer Discretionary   76.30
# ZBH     Zimmer Biomet Holdings             Health Care  115.53
# ZION             Zions Bancorp              Financials   50.71
# ZTS                     Zoetis             Health Care   71.51
#
# [505 rows x 3 columns]

# %%
# we can retrieve individual rows from the dataframe
df.loc['ZION']
# retrieve the rows for YUM, XYL and FB
df.loc[['YUM', 'XYL', 'FB']] # provide a list of the required values
# Out:
#                    Name                  Sector   Price  Price/Earnings  \
# Symbol
# YUM     Yum! Brands Inc  Consumer Discretionary   76.30           27.25
# XYL          Xylem Inc.             Industrials   70.24           30.94
# FB       Facebook, Inc.  Information Technology  171.58           27.90
#
#         Earnings/Share  52 Week High  52 Week Low
# Symbol
# YUM               4.07         86.93        62.85
# XYL               1.83         76.81        46.86
# FB                5.39        195.32       132.44
