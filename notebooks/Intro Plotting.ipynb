# %% [markdown]
# # Introduction to Plotting with matplotlib.pyplot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(io='../Data/plotting_data.xls', sheet_name='anscombe', index_col='ID')
df.head(3)
# Out:
#    dataset   x     y
# ID
# 0        I  10  8.04
# 1        I   8  6.95
# 2        I  13  7.58

# %%
# plot only th 'I' data set
fltr = df['dataset'] == 'I' 
fltr # bunch of true and false values
df_I = df[fltr] # we now have a new DataFrame containing olny 'I' data
df_I
xI = df_I['x']
yI = df_I['y']
#plot
plt.plot(xI, yI, 'x') # or 'o' etc.

# %%
# please plot data for 'II' using a line chart
# also 'III' and 'IV' as separate plots of your own design
df_I = df[df['dataset'] == 'I'] # already got this one!!
df_II = df[df['dataset'] == 'II']
df_III = df[df['dataset'] == 'III']
df_IV = df[df['dataset'] == 'IV']
# II
xII = df_II['x']
yII = df_II['y']
#plot
plt.plot(xII, yII) # a line chart

# %%
# III
xIII = df_III['x']
yIII = df_III['y']
#plot
plt.plot(xIII, yIII, 'o') # a scatter chart

# %%
xIV = df_IV['x']_
#plot
plt.plot(xIV, yIV, '.') # or 'o' etc.

# %%
# one figure with many plots
# Create a Figure
fig = plt.figure(figsize=(18,6))

# Add 4 subplots
# subplot takes (num rows, num columns, plot location)
ax1 = fig.add_subplot(2,2,1) # (2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# plot each dataset on its corresponding sub_plot
ax1.plot(df_I['x'], df_I['y'], 'o')
ax2.plot(df_II['x'], df_II['y'], 'o')
ax3.plot(df_III['x'], df_III['y'], 'o')
ax4.plot(df_IV['x'], df_IV['y'], 'o')

# Add some titles etc
ax1.set_title('Dataset I')
ax2.set_title('Dataset II')
ax3.set_title('Dataset III')
ax4.set_title('Dataset IV')

# Title of entire figure
fig.suptitle("Anscombe Data") # NB sup title

# Use a tight layout
fig.tight_layout()
